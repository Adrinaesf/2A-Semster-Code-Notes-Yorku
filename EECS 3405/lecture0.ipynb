# %%
companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]
first_slice = companies[:3]
last_slice = companies[4:]
companies.remove(companies[int(len(companies) / 2)])
print(companies)
print(first_slice)
print(last_slice)

# def factorial(n):
# Out:
# ['Facebook', 'Google', 'Microsoft', 'IBM', 'Oracle', 'Amazon']
# ['Facebook', 'Google', 'Microsoft']
# ['IBM', 'Oracle', 'Amazon']
